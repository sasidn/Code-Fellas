# %%
from kafka import KafkaConsumer
import json
from pymongo import MongoClient
#from mongoConnect import insertNewsWire

# %%
# Kafka consumer to retrieve messages from Kafka topic - 'nytWire' 
consumer = KafkaConsumer(
        "godfather", # topic
        bootstrap_servers = ['localhost:9092'],
        auto_offset_reset = 'earliest', #tells the new consumer to start consuming from the earliest
        group_id = "consumer-group-nytWire") #providing a consumer group id

# %%
# connect to mongo and desired database
try:
   #client = MongoClient("mongodb+srv://de2_codefellas:lolwa123@cluster0.zobt8p2.mongodb.net/?retryWrites=true&w=majority")
   client = MongoClient('mongodb://localhost:27017')
   db = client.Nissy
   collection = db.Movie
   print("Connected successfully!!!")
except:  
   print("Could not connect to MongoDB")
# Out:
# Connected successfully!!!

# %%
for msg in consumer:
    print('Hello')
    print('msg')
    record = json.loads(msg.value)
    print(record)
    #display_title = record['display_title']
    rec_id1 = db.PopularReview.insert_one(record)
    print("Data inserted with record ids", rec_id1)
# Out:
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather, Part II', 'critics_pick': 1, 'headline': 'Godfather: Part II, The (Movie)', 'publication_date': '1974-12-13', 'summary_short': ''}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F1F0>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Black Godfather', 'critics_pick': 0, 'headline': 'Black Godfather, The (Movie)', 'publication_date': '1974-09-04', 'summary_short': ''}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F520>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather', 'critics_pick': 1, 'headline': 'THE GODFATHER (MOVIE)', 'publication_date': '1972-03-16', 'summary_short': "Puzo's Mafioso novel. Scalding and memorable."}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F070>
# Hello
# msg
# {'mpaa_rating': 'Passed', 'display_title': 'Three Godfathers', 'critics_pick': 0, 'headline': 'Three Godfathers', 'publication_date': '1949-03-04', 'summary_short': 'Outlaw trio and abandoned child. Typical, expert Ford western.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F460>
# Hello
# msg
# {'mpaa_rating': 'Passed', 'display_title': 'Miracle in the Sand', 'critics_pick': 0, 'headline': 'Three Godfathers, The', 'publication_date': '1936-03-09', 'summary_short': 'Thieves reluctantly care for orphan. Tragic horse opera.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F250>
# Hello
# msg
# {'mpaa_rating': '', 'display_title': 'El Compadre Mendoza', 'critics_pick': 0, 'headline': 'Compadre Mendoza, El', 'publication_date': '1934-11-19', 'summary_short': 'Landowner survives Mexican Revolution by supporting both sides. Directed by Fernando de Fuentes.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F4C0>
# Hello
# msg
# {'mpaa_rating': 'TV-MA', 'display_title': 'The Black Godfather', 'critics_pick': 0, 'headline': '‘The Black Godfather’ Review: The Music Executive Who Made It All Happen', 'publication_date': '2019-06-06', 'summary_short': 'Reginald Hudlin’s documentary about Clarence Avant includes many golden anecdotes.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F250>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'Square Grouper: The Godfathers of Ganja', 'critics_pick': 0, 'headline': 'Adventures in the Drug Trades', 'publication_date': '2011-04-14', 'summary_short': '“Square Grouper” is a documentary about pot smuggling in South Florida in the 1970s and ’80s.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F160>
# Hello
# msg
# {'mpaa_rating': 'PG-13', 'display_title': 'Tokyo Godfathers', 'critics_pick': 1, 'headline': 'Three Down-and-Outs Rescue a Foundling From the Trash', 'publication_date': '2004-01-16', 'summary_short': "Another marvel from Satoshi Kon, whose first two films, &quot;Perfect Blue&quot; and &quot;Millennium Actress,&quot; have already pushed Japanese feature-length animation toward greater realism and wilder fantasy. Loosely based on &quot;3 Godfathers,&quot; John Ford's maudlin 1948 western, this movie, a sweet fable of decency amid the down and out, also has echoes of Chaplin and Capra. Three homeless people — an embittered alcoholic, a middle-aged transvestite and a teenage runaway — find an abandoned baby on Christmas Eve. As they try to reunite the foundling with her parents, they revisit their own unhappy lives, and travel through a city rendered with unbelievable precision and tinted with undeniable love. The potentially sticky sentiments of the story are balanced by a crazily inventive narrative and by Mr. Kon's cool, obsessively detailed visual style. At the end, the skyscrapers of Tokyo wriggle and dance to a Japanese-language techno version of Beethoven's &quot;Ode to Joy,&quot; which pretty much sums up this indescribable, unforgettable movie. — A. O. Scott"}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F460>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather, Part III', 'critics_pick': 1, 'headline': 'GODFATHER PART III (MOVIE)', 'publication_date': '1990-12-25', 'summary_short': "Mafia heir trapped by legacy of past. Coppola's director's cut. Deeply moving."}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F4F0>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather, Part II', 'critics_pick': 1, 'headline': 'Godfather: Part II, The (Movie)', 'publication_date': '1974-12-13', 'summary_short': ''}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F580>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Black Godfather', 'critics_pick': 0, 'headline': 'Black Godfather, The (Movie)', 'publication_date': '1974-09-04', 'summary_short': ''}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F2B0>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather', 'critics_pick': 1, 'headline': 'THE GODFATHER (MOVIE)', 'publication_date': '1972-03-16', 'summary_short': "Puzo's Mafioso novel. Scalding and memorable."}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F370>
# Hello
# msg
# {'mpaa_rating': 'Passed', 'display_title': 'Three Godfathers', 'critics_pick': 0, 'headline': 'Three Godfathers', 'publication_date': '1949-03-04', 'summary_short': 'Outlaw trio and abandoned child. Typical, expert Ford western.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2EEF0>
# Hello
# msg
# {'mpaa_rating': 'Passed', 'display_title': 'Miracle in the Sand', 'critics_pick': 0, 'headline': 'Three Godfathers, The', 'publication_date': '1936-03-09', 'summary_short': 'Thieves reluctantly care for orphan. Tragic horse opera.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F730>
# Hello
# msg
# {'mpaa_rating': '', 'display_title': 'El Compadre Mendoza', 'critics_pick': 0, 'headline': 'Compadre Mendoza, El', 'publication_date': '1934-11-19', 'summary_short': 'Landowner survives Mexican Revolution by supporting both sides. Directed by Fernando de Fuentes.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F130>
# Hello
# msg
# {'mpaa_rating': 'TV-MA', 'display_title': 'The Black Godfather', 'critics_pick': 0, 'headline': '‘The Black Godfather’ Review: The Music Executive Who Made It All Happen', 'publication_date': '2019-06-06', 'summary_short': 'Reginald Hudlin’s documentary about Clarence Avant includes many golden anecdotes.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F5E0>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'Square Grouper: The Godfathers of Ganja', 'critics_pick': 0, 'headline': 'Adventures in the Drug Trades', 'publication_date': '2011-04-14', 'summary_short': '“Square Grouper” is a documentary about pot smuggling in South Florida in the 1970s and ’80s.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F700>
# Hello
# msg
# {'mpaa_rating': 'PG-13', 'display_title': 'Tokyo Godfathers', 'critics_pick': 1, 'headline': 'Three Down-and-Outs Rescue a Foundling From the Trash', 'publication_date': '2004-01-16', 'summary_short': "Another marvel from Satoshi Kon, whose first two films, &quot;Perfect Blue&quot; and &quot;Millennium Actress,&quot; have already pushed Japanese feature-length animation toward greater realism and wilder fantasy. Loosely based on &quot;3 Godfathers,&quot; John Ford's maudlin 1948 western, this movie, a sweet fable of decency amid the down and out, also has echoes of Chaplin and Capra. Three homeless people — an embittered alcoholic, a middle-aged transvestite and a teenage runaway — find an abandoned baby on Christmas Eve. As they try to reunite the foundling with her parents, they revisit their own unhappy lives, and travel through a city rendered with unbelievable precision and tinted with undeniable love. The potentially sticky sentiments of the story are balanced by a crazily inventive narrative and by Mr. Kon's cool, obsessively detailed visual style. At the end, the skyscrapers of Tokyo wriggle and dance to a Japanese-language techno version of Beethoven's &quot;Ode to Joy,&quot; which pretty much sums up this indescribable, unforgettable movie. — A. O. Scott"}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F6D0>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather, Part III', 'critics_pick': 1, 'headline': 'GODFATHER PART III (MOVIE)', 'publication_date': '1990-12-25', 'summary_short': "Mafia heir trapped by legacy of past. Coppola's director's cut. Deeply moving."}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F310>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather, Part II', 'critics_pick': 1, 'headline': 'Godfather: Part II, The (Movie)', 'publication_date': '1974-12-13', 'summary_short': ''}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F400>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Black Godfather', 'critics_pick': 0, 'headline': 'Black Godfather, The (Movie)', 'publication_date': '1974-09-04', 'summary_short': ''}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F580>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather', 'critics_pick': 1, 'headline': 'THE GODFATHER (MOVIE)', 'publication_date': '1972-03-16', 'summary_short': "Puzo's Mafioso novel. Scalding and memorable."}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F460>
# Hello
# msg
# {'mpaa_rating': 'Passed', 'display_title': 'Three Godfathers', 'critics_pick': 0, 'headline': 'Three Godfathers', 'publication_date': '1949-03-04', 'summary_short': 'Outlaw trio and abandoned child. Typical, expert Ford western.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F130>
# Hello
# msg
# {'mpaa_rating': 'Passed', 'display_title': 'Miracle in the Sand', 'critics_pick': 0, 'headline': 'Three Godfathers, The', 'publication_date': '1936-03-09', 'summary_short': 'Thieves reluctantly care for orphan. Tragic horse opera.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F0A0>
# Hello
# msg
# {'mpaa_rating': '', 'display_title': 'El Compadre Mendoza', 'critics_pick': 0, 'headline': 'Compadre Mendoza, El', 'publication_date': '1934-11-19', 'summary_short': 'Landowner survives Mexican Revolution by supporting both sides. Directed by Fernando de Fuentes.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F700>
# Hello
# msg
# {'mpaa_rating': 'TV-MA', 'display_title': 'The Black Godfather', 'critics_pick': 0, 'headline': '‘The Black Godfather’ Review: The Music Executive Who Made It All Happen', 'publication_date': '2019-06-06', 'summary_short': 'Reginald Hudlin’s documentary about Clarence Avant includes many golden anecdotes.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F4C0>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'Square Grouper: The Godfathers of Ganja', 'critics_pick': 0, 'headline': 'Adventures in the Drug Trades', 'publication_date': '2011-04-14', 'summary_short': '“Square Grouper” is a documentary about pot smuggling in South Florida in the 1970s and ’80s.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F4F0>
# Hello
# msg
# {'mpaa_rating': 'PG-13', 'display_title': 'Tokyo Godfathers', 'critics_pick': 1, 'headline': 'Three Down-and-Outs Rescue a Foundling From the Trash', 'publication_date': '2004-01-16', 'summary_short': "Another marvel from Satoshi Kon, whose first two films, &quot;Perfect Blue&quot; and &quot;Millennium Actress,&quot; have already pushed Japanese feature-length animation toward greater realism and wilder fantasy. Loosely based on &quot;3 Godfathers,&quot; John Ford's maudlin 1948 western, this movie, a sweet fable of decency amid the down and out, also has echoes of Chaplin and Capra. Three homeless people — an embittered alcoholic, a middle-aged transvestite and a teenage runaway — find an abandoned baby on Christmas Eve. As they try to reunite the foundling with her parents, they revisit their own unhappy lives, and travel through a city rendered with unbelievable precision and tinted with undeniable love. The potentially sticky sentiments of the story are balanced by a crazily inventive narrative and by Mr. Kon's cool, obsessively detailed visual style. At the end, the skyscrapers of Tokyo wriggle and dance to a Japanese-language techno version of Beethoven's &quot;Ode to Joy,&quot; which pretty much sums up this indescribable, unforgettable movie. — A. O. Scott"}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F190>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather, Part III', 'critics_pick': 1, 'headline': 'GODFATHER PART III (MOVIE)', 'publication_date': '1990-12-25', 'summary_short': "Mafia heir trapped by legacy of past. Coppola's director's cut. Deeply moving."}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F1F0>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather, Part II', 'critics_pick': 1, 'headline': 'Godfather: Part II, The (Movie)', 'publication_date': '1974-12-13', 'summary_short': ''}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F070>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Black Godfather', 'critics_pick': 0, 'headline': 'Black Godfather, The (Movie)', 'publication_date': '1974-09-04', 'summary_short': ''}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2EF20>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather', 'critics_pick': 1, 'headline': 'THE GODFATHER (MOVIE)', 'publication_date': '1972-03-16', 'summary_short': "Puzo's Mafioso novel. Scalding and memorable."}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F730>
# Hello
# msg
# {'mpaa_rating': 'Passed', 'display_title': 'Three Godfathers', 'critics_pick': 0, 'headline': 'Three Godfathers', 'publication_date': '1949-03-04', 'summary_short': 'Outlaw trio and abandoned child. Typical, expert Ford western.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F5E0>
# Hello
# msg
# {'mpaa_rating': 'Passed', 'display_title': 'Miracle in the Sand', 'critics_pick': 0, 'headline': 'Three Godfathers, The', 'publication_date': '1936-03-09', 'summary_short': 'Thieves reluctantly care for orphan. Tragic horse opera.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F370>
# Hello
# msg
# {'mpaa_rating': '', 'display_title': 'El Compadre Mendoza', 'critics_pick': 0, 'headline': 'Compadre Mendoza, El', 'publication_date': '1934-11-19', 'summary_short': 'Landowner survives Mexican Revolution by supporting both sides. Directed by Fernando de Fuentes.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2EEF0>
# Hello
# msg
# {'mpaa_rating': 'TV-MA', 'display_title': 'The Black Godfather', 'critics_pick': 0, 'headline': '‘The Black Godfather’ Review: The Music Executive Who Made It All Happen', 'publication_date': '2019-06-06', 'summary_short': 'Reginald Hudlin’s documentary about Clarence Avant includes many golden anecdotes.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F550>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'Square Grouper: The Godfathers of Ganja', 'critics_pick': 0, 'headline': 'Adventures in the Drug Trades', 'publication_date': '2011-04-14', 'summary_short': '“Square Grouper” is a documentary about pot smuggling in South Florida in the 1970s and ’80s.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F2B0>
# Hello
# msg
# {'mpaa_rating': 'PG-13', 'display_title': 'Tokyo Godfathers', 'critics_pick': 1, 'headline': 'Three Down-and-Outs Rescue a Foundling From the Trash', 'publication_date': '2004-01-16', 'summary_short': "Another marvel from Satoshi Kon, whose first two films, &quot;Perfect Blue&quot; and &quot;Millennium Actress,&quot; have already pushed Japanese feature-length animation toward greater realism and wilder fantasy. Loosely based on &quot;3 Godfathers,&quot; John Ford's maudlin 1948 western, this movie, a sweet fable of decency amid the down and out, also has echoes of Chaplin and Capra. Three homeless people — an embittered alcoholic, a middle-aged transvestite and a teenage runaway — find an abandoned baby on Christmas Eve. As they try to reunite the foundling with her parents, they revisit their own unhappy lives, and travel through a city rendered with unbelievable precision and tinted with undeniable love. The potentially sticky sentiments of the story are balanced by a crazily inventive narrative and by Mr. Kon's cool, obsessively detailed visual style. At the end, the skyscrapers of Tokyo wriggle and dance to a Japanese-language techno version of Beethoven's &quot;Ode to Joy,&quot; which pretty much sums up this indescribable, unforgettable movie. — A. O. Scott"}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F160>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather, Part III', 'critics_pick': 1, 'headline': 'GODFATHER PART III (MOVIE)', 'publication_date': '1990-12-25', 'summary_short': "Mafia heir trapped by legacy of past. Coppola's director's cut. Deeply moving."}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F460>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather, Part II', 'critics_pick': 1, 'headline': 'Godfather: Part II, The (Movie)', 'publication_date': '1974-12-13', 'summary_short': ''}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F610>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Black Godfather', 'critics_pick': 0, 'headline': 'Black Godfather, The (Movie)', 'publication_date': '1974-09-04', 'summary_short': ''}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F640>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather', 'critics_pick': 1, 'headline': 'THE GODFATHER (MOVIE)', 'publication_date': '1972-03-16', 'summary_short': "Puzo's Mafioso novel. Scalding and memorable."}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F730>
# Hello
# msg
# {'mpaa_rating': 'Passed', 'display_title': 'Three Godfathers', 'critics_pick': 0, 'headline': 'Three Godfathers', 'publication_date': '1949-03-04', 'summary_short': 'Outlaw trio and abandoned child. Typical, expert Ford western.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F310>
# Hello
# msg
# {'mpaa_rating': 'Passed', 'display_title': 'Miracle in the Sand', 'critics_pick': 0, 'headline': 'Three Godfathers, The', 'publication_date': '1936-03-09', 'summary_short': 'Thieves reluctantly care for orphan. Tragic horse opera.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F160>
# Hello
# msg
# {'mpaa_rating': '', 'display_title': 'El Compadre Mendoza', 'critics_pick': 0, 'headline': 'Compadre Mendoza, El', 'publication_date': '1934-11-19', 'summary_short': 'Landowner survives Mexican Revolution by supporting both sides. Directed by Fernando de Fuentes.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F1C0>
# Hello
# msg
# {'mpaa_rating': 'TV-MA', 'display_title': 'The Black Godfather', 'critics_pick': 0, 'headline': '‘The Black Godfather’ Review: The Music Executive Who Made It All Happen', 'publication_date': '2019-06-06', 'summary_short': 'Reginald Hudlin’s documentary about Clarence Avant includes many golden anecdotes.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2EF80>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'Square Grouper: The Godfathers of Ganja', 'critics_pick': 0, 'headline': 'Adventures in the Drug Trades', 'publication_date': '2011-04-14', 'summary_short': '“Square Grouper” is a documentary about pot smuggling in South Florida in the 1970s and ’80s.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F070>
# Hello
# msg
# {'mpaa_rating': 'PG-13', 'display_title': 'Tokyo Godfathers', 'critics_pick': 1, 'headline': 'Three Down-and-Outs Rescue a Foundling From the Trash', 'publication_date': '2004-01-16', 'summary_short': "Another marvel from Satoshi Kon, whose first two films, &quot;Perfect Blue&quot; and &quot;Millennium Actress,&quot; have already pushed Japanese feature-length animation toward greater realism and wilder fantasy. Loosely based on &quot;3 Godfathers,&quot; John Ford's maudlin 1948 western, this movie, a sweet fable of decency amid the down and out, also has echoes of Chaplin and Capra. Three homeless people — an embittered alcoholic, a middle-aged transvestite and a teenage runaway — find an abandoned baby on Christmas Eve. As they try to reunite the foundling with her parents, they revisit their own unhappy lives, and travel through a city rendered with unbelievable precision and tinted with undeniable love. The potentially sticky sentiments of the story are balanced by a crazily inventive narrative and by Mr. Kon's cool, obsessively detailed visual style. At the end, the skyscrapers of Tokyo wriggle and dance to a Japanese-language techno version of Beethoven's &quot;Ode to Joy,&quot; which pretty much sums up this indescribable, unforgettable movie. — A. O. Scott"}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F6D0>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather, Part III', 'critics_pick': 1, 'headline': 'GODFATHER PART III (MOVIE)', 'publication_date': '1990-12-25', 'summary_short': "Mafia heir trapped by legacy of past. Coppola's director's cut. Deeply moving."}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F490>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather, Part II', 'critics_pick': 1, 'headline': 'Godfather: Part II, The (Movie)', 'publication_date': '1974-12-13', 'summary_short': ''}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F520>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Black Godfather', 'critics_pick': 0, 'headline': 'Black Godfather, The (Movie)', 'publication_date': '1974-09-04', 'summary_short': ''}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F670>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather', 'critics_pick': 1, 'headline': 'THE GODFATHER (MOVIE)', 'publication_date': '1972-03-16', 'summary_short': "Puzo's Mafioso novel. Scalding and memorable."}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F130>
# Hello
# msg
# {'mpaa_rating': 'Passed', 'display_title': 'Three Godfathers', 'critics_pick': 0, 'headline': 'Three Godfathers', 'publication_date': '1949-03-04', 'summary_short': 'Outlaw trio and abandoned child. Typical, expert Ford western.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F010>
# Hello
# msg
# {'mpaa_rating': 'Passed', 'display_title': 'Miracle in the Sand', 'critics_pick': 0, 'headline': 'Three Godfathers, The', 'publication_date': '1936-03-09', 'summary_short': 'Thieves reluctantly care for orphan. Tragic horse opera.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F070>
# Hello
# msg
# {'mpaa_rating': '', 'display_title': 'El Compadre Mendoza', 'critics_pick': 0, 'headline': 'Compadre Mendoza, El', 'publication_date': '1934-11-19', 'summary_short': 'Landowner survives Mexican Revolution by supporting both sides. Directed by Fernando de Fuentes.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F520>
# Hello
# msg
# {'mpaa_rating': 'TV-MA', 'display_title': 'The Black Godfather', 'critics_pick': 0, 'headline': '‘The Black Godfather’ Review: The Music Executive Who Made It All Happen', 'publication_date': '2019-06-06', 'summary_short': 'Reginald Hudlin’s documentary about Clarence Avant includes many golden anecdotes.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F160>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'Square Grouper: The Godfathers of Ganja', 'critics_pick': 0, 'headline': 'Adventures in the Drug Trades', 'publication_date': '2011-04-14', 'summary_short': '“Square Grouper” is a documentary about pot smuggling in South Florida in the 1970s and ’80s.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2EF80>
# Hello
# msg
# {'mpaa_rating': 'PG-13', 'display_title': 'Tokyo Godfathers', 'critics_pick': 1, 'headline': 'Three Down-and-Outs Rescue a Foundling From the Trash', 'publication_date': '2004-01-16', 'summary_short': "Another marvel from Satoshi Kon, whose first two films, &quot;Perfect Blue&quot; and &quot;Millennium Actress,&quot; have already pushed Japanese feature-length animation toward greater realism and wilder fantasy. Loosely based on &quot;3 Godfathers,&quot; John Ford's maudlin 1948 western, this movie, a sweet fable of decency amid the down and out, also has echoes of Chaplin and Capra. Three homeless people — an embittered alcoholic, a middle-aged transvestite and a teenage runaway — find an abandoned baby on Christmas Eve. As they try to reunite the foundling with her parents, they revisit their own unhappy lives, and travel through a city rendered with unbelievable precision and tinted with undeniable love. The potentially sticky sentiments of the story are balanced by a crazily inventive narrative and by Mr. Kon's cool, obsessively detailed visual style. At the end, the skyscrapers of Tokyo wriggle and dance to a Japanese-language techno version of Beethoven's &quot;Ode to Joy,&quot; which pretty much sums up this indescribable, unforgettable movie. — A. O. Scott"}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F250>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather, Part III', 'critics_pick': 1, 'headline': 'GODFATHER PART III (MOVIE)', 'publication_date': '1990-12-25', 'summary_short': "Mafia heir trapped by legacy of past. Coppola's director's cut. Deeply moving."}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F010>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather, Part II', 'critics_pick': 1, 'headline': 'Godfather: Part II, The (Movie)', 'publication_date': '1974-12-13', 'summary_short': ''}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F0A0>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Black Godfather', 'critics_pick': 0, 'headline': 'Black Godfather, The (Movie)', 'publication_date': '1974-09-04', 'summary_short': ''}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F670>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather', 'critics_pick': 1, 'headline': 'THE GODFATHER (MOVIE)', 'publication_date': '1972-03-16', 'summary_short': "Puzo's Mafioso novel. Scalding and memorable."}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2EC20>
# Hello
# msg
# {'mpaa_rating': 'Passed', 'display_title': 'Three Godfathers', 'critics_pick': 0, 'headline': 'Three Godfathers', 'publication_date': '1949-03-04', 'summary_short': 'Outlaw trio and abandoned child. Typical, expert Ford western.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F520>
# Hello
# msg
# {'mpaa_rating': 'Passed', 'display_title': 'Miracle in the Sand', 'critics_pick': 0, 'headline': 'Three Godfathers, The', 'publication_date': '1936-03-09', 'summary_short': 'Thieves reluctantly care for orphan. Tragic horse opera.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F3A0>
# Hello
# msg
# {'mpaa_rating': '', 'display_title': 'El Compadre Mendoza', 'critics_pick': 0, 'headline': 'Compadre Mendoza, El', 'publication_date': '1934-11-19', 'summary_short': 'Landowner survives Mexican Revolution by supporting both sides. Directed by Fernando de Fuentes.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F790>
# Hello
# msg
# {'mpaa_rating': 'TV-MA', 'display_title': 'The Black Godfather', 'critics_pick': 0, 'headline': '‘The Black Godfather’ Review: The Music Executive Who Made It All Happen', 'publication_date': '2019-06-06', 'summary_short': 'Reginald Hudlin’s documentary about Clarence Avant includes many golden anecdotes.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F490>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'Square Grouper: The Godfathers of Ganja', 'critics_pick': 0, 'headline': 'Adventures in the Drug Trades', 'publication_date': '2011-04-14', 'summary_short': '“Square Grouper” is a documentary about pot smuggling in South Florida in the 1970s and ’80s.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F730>
# Hello
# msg
# {'mpaa_rating': 'PG-13', 'display_title': 'Tokyo Godfathers', 'critics_pick': 1, 'headline': 'Three Down-and-Outs Rescue a Foundling From the Trash', 'publication_date': '2004-01-16', 'summary_short': "Another marvel from Satoshi Kon, whose first two films, &quot;Perfect Blue&quot; and &quot;Millennium Actress,&quot; have already pushed Japanese feature-length animation toward greater realism and wilder fantasy. Loosely based on &quot;3 Godfathers,&quot; John Ford's maudlin 1948 western, this movie, a sweet fable of decency amid the down and out, also has echoes of Chaplin and Capra. Three homeless people — an embittered alcoholic, a middle-aged transvestite and a teenage runaway — find an abandoned baby on Christmas Eve. As they try to reunite the foundling with her parents, they revisit their own unhappy lives, and travel through a city rendered with unbelievable precision and tinted with undeniable love. The potentially sticky sentiments of the story are balanced by a crazily inventive narrative and by Mr. Kon's cool, obsessively detailed visual style. At the end, the skyscrapers of Tokyo wriggle and dance to a Japanese-language techno version of Beethoven's &quot;Ode to Joy,&quot; which pretty much sums up this indescribable, unforgettable movie. — A. O. Scott"}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F640>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather, Part III', 'critics_pick': 1, 'headline': 'GODFATHER PART III (MOVIE)', 'publication_date': '1990-12-25', 'summary_short': "Mafia heir trapped by legacy of past. Coppola's director's cut. Deeply moving."}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F520>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather, Part II', 'critics_pick': 1, 'headline': 'Godfather: Part II, The (Movie)', 'publication_date': '1974-12-13', 'summary_short': ''}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F760>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Black Godfather', 'critics_pick': 0, 'headline': 'Black Godfather, The (Movie)', 'publication_date': '1974-09-04', 'summary_short': ''}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F0D0>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather', 'critics_pick': 1, 'headline': 'THE GODFATHER (MOVIE)', 'publication_date': '1972-03-16', 'summary_short': "Puzo's Mafioso novel. Scalding and memorable."}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F370>
# Hello
# msg
# {'mpaa_rating': 'Passed', 'display_title': 'Three Godfathers', 'critics_pick': 0, 'headline': 'Three Godfathers', 'publication_date': '1949-03-04', 'summary_short': 'Outlaw trio and abandoned child. Typical, expert Ford western.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283ED8DA50>
# Hello
# msg
# {'mpaa_rating': 'Passed', 'display_title': 'Miracle in the Sand', 'critics_pick': 0, 'headline': 'Three Godfathers, The', 'publication_date': '1936-03-09', 'summary_short': 'Thieves reluctantly care for orphan. Tragic horse opera.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EC55600>
# Hello
# msg
# {'mpaa_rating': '', 'display_title': 'El Compadre Mendoza', 'critics_pick': 0, 'headline': 'Compadre Mendoza, El', 'publication_date': '1934-11-19', 'summary_short': 'Landowner survives Mexican Revolution by supporting both sides. Directed by Fernando de Fuentes.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283ED8D900>
# Hello
# msg
# {'mpaa_rating': 'TV-MA', 'display_title': 'The Black Godfather', 'critics_pick': 0, 'headline': '‘The Black Godfather’ Review: The Music Executive Who Made It All Happen', 'publication_date': '2019-06-06', 'summary_short': 'Reginald Hudlin’s documentary about Clarence Avant includes many golden anecdotes.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283ED8D8D0>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'Square Grouper: The Godfathers of Ganja', 'critics_pick': 0, 'headline': 'Adventures in the Drug Trades', 'publication_date': '2011-04-14', 'summary_short': '“Square Grouper” is a documentary about pot smuggling in South Florida in the 1970s and ’80s.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EC48BB0>
# Hello
# msg
# {'mpaa_rating': 'PG-13', 'display_title': 'Tokyo Godfathers', 'critics_pick': 1, 'headline': 'Three Down-and-Outs Rescue a Foundling From the Trash', 'publication_date': '2004-01-16', 'summary_short': "Another marvel from Satoshi Kon, whose first two films, &quot;Perfect Blue&quot; and &quot;Millennium Actress,&quot; have already pushed Japanese feature-length animation toward greater realism and wilder fantasy. Loosely based on &quot;3 Godfathers,&quot; John Ford's maudlin 1948 western, this movie, a sweet fable of decency amid the down and out, also has echoes of Chaplin and Capra. Three homeless people — an embittered alcoholic, a middle-aged transvestite and a teenage runaway — find an abandoned baby on Christmas Eve. As they try to reunite the foundling with her parents, they revisit their own unhappy lives, and travel through a city rendered with unbelievable precision and tinted with undeniable love. The potentially sticky sentiments of the story are balanced by a crazily inventive narrative and by Mr. Kon's cool, obsessively detailed visual style. At the end, the skyscrapers of Tokyo wriggle and dance to a Japanese-language techno version of Beethoven's &quot;Ode to Joy,&quot; which pretty much sums up this indescribable, unforgettable movie. — A. O. Scott"}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283ED8D0C0>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather, Part III', 'critics_pick': 1, 'headline': 'GODFATHER PART III (MOVIE)', 'publication_date': '1990-12-25', 'summary_short': "Mafia heir trapped by legacy of past. Coppola's director's cut. Deeply moving."}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283ED8CCA0>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather, Part II', 'critics_pick': 1, 'headline': 'Godfather: Part II, The (Movie)', 'publication_date': '1974-12-13', 'summary_short': ''}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283D1AAE60>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Black Godfather', 'critics_pick': 0, 'headline': 'Black Godfather, The (Movie)', 'publication_date': '1974-09-04', 'summary_short': ''}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283ED8CCA0>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather', 'critics_pick': 1, 'headline': 'THE GODFATHER (MOVIE)', 'publication_date': '1972-03-16', 'summary_short': "Puzo's Mafioso novel. Scalding and memorable."}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283ED8D8D0>
# Hello
# msg
# {'mpaa_rating': 'Passed', 'display_title': 'Three Godfathers', 'critics_pick': 0, 'headline': 'Three Godfathers', 'publication_date': '1949-03-04', 'summary_short': 'Outlaw trio and abandoned child. Typical, expert Ford western.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2DF00>
# Hello
# msg
# {'mpaa_rating': 'Passed', 'display_title': 'Miracle in the Sand', 'critics_pick': 0, 'headline': 'Three Godfathers, The', 'publication_date': '1936-03-09', 'summary_short': 'Thieves reluctantly care for orphan. Tragic horse opera.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283D1AAE60>
# Hello
# msg
# {'mpaa_rating': '', 'display_title': 'El Compadre Mendoza', 'critics_pick': 0, 'headline': 'Compadre Mendoza, El', 'publication_date': '1934-11-19', 'summary_short': 'Landowner survives Mexican Revolution by supporting both sides. Directed by Fernando de Fuentes.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283ED8D0C0>
# Hello
# msg
# {'mpaa_rating': 'TV-MA', 'display_title': 'The Black Godfather', 'critics_pick': 0, 'headline': '‘The Black Godfather’ Review: The Music Executive Who Made It All Happen', 'publication_date': '2019-06-06', 'summary_short': 'Reginald Hudlin’s documentary about Clarence Avant includes many golden anecdotes.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F490>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'Square Grouper: The Godfathers of Ganja', 'critics_pick': 0, 'headline': 'Adventures in the Drug Trades', 'publication_date': '2011-04-14', 'summary_short': '“Square Grouper” is a documentary about pot smuggling in South Florida in the 1970s and ’80s.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283ED8D0C0>
# Hello
# msg
# {'mpaa_rating': 'PG-13', 'display_title': 'Tokyo Godfathers', 'critics_pick': 1, 'headline': 'Three Down-and-Outs Rescue a Foundling From the Trash', 'publication_date': '2004-01-16', 'summary_short': "Another marvel from Satoshi Kon, whose first two films, &quot;Perfect Blue&quot; and &quot;Millennium Actress,&quot; have already pushed Japanese feature-length animation toward greater realism and wilder fantasy. Loosely based on &quot;3 Godfathers,&quot; John Ford's maudlin 1948 western, this movie, a sweet fable of decency amid the down and out, also has echoes of Chaplin and Capra. Three homeless people — an embittered alcoholic, a middle-aged transvestite and a teenage runaway — find an abandoned baby on Christmas Eve. As they try to reunite the foundling with her parents, they revisit their own unhappy lives, and travel through a city rendered with unbelievable precision and tinted with undeniable love. The potentially sticky sentiments of the story are balanced by a crazily inventive narrative and by Mr. Kon's cool, obsessively detailed visual style. At the end, the skyscrapers of Tokyo wriggle and dance to a Japanese-language techno version of Beethoven's &quot;Ode to Joy,&quot; which pretty much sums up this indescribable, unforgettable movie. — A. O. Scott"}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EDF11E0>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather, Part III', 'critics_pick': 1, 'headline': 'GODFATHER PART III (MOVIE)', 'publication_date': '1990-12-25', 'summary_short': "Mafia heir trapped by legacy of past. Coppola's director's cut. Deeply moving."}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283D1AAE60>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather, Part II', 'critics_pick': 1, 'headline': 'Godfather: Part II, The (Movie)', 'publication_date': '1974-12-13', 'summary_short': ''}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283ED8CCA0>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Black Godfather', 'critics_pick': 0, 'headline': 'Black Godfather, The (Movie)', 'publication_date': '1974-09-04', 'summary_short': ''}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283ED8D8D0>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather', 'critics_pick': 1, 'headline': 'THE GODFATHER (MOVIE)', 'publication_date': '1972-03-16', 'summary_short': "Puzo's Mafioso novel. Scalding and memorable."}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283ED8CCA0>
# Hello
# msg
# {'mpaa_rating': 'Passed', 'display_title': 'Three Godfathers', 'critics_pick': 0, 'headline': 'Three Godfathers', 'publication_date': '1949-03-04', 'summary_short': 'Outlaw trio and abandoned child. Typical, expert Ford western.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2DA50>
# Hello
# msg
# {'mpaa_rating': 'Passed', 'display_title': 'Miracle in the Sand', 'critics_pick': 0, 'headline': 'Three Godfathers, The', 'publication_date': '1936-03-09', 'summary_short': 'Thieves reluctantly care for orphan. Tragic horse opera.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283ED8D1B0>
# Hello
# msg
# {'mpaa_rating': '', 'display_title': 'El Compadre Mendoza', 'critics_pick': 0, 'headline': 'Compadre Mendoza, El', 'publication_date': '1934-11-19', 'summary_short': 'Landowner survives Mexican Revolution by supporting both sides. Directed by Fernando de Fuentes.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283ED8D0C0>
# Hello
# msg
# {'mpaa_rating': 'TV-MA', 'display_title': 'The Black Godfather', 'critics_pick': 0, 'headline': '‘The Black Godfather’ Review: The Music Executive Who Made It All Happen', 'publication_date': '2019-06-06', 'summary_short': 'Reginald Hudlin’s documentary about Clarence Avant includes many golden anecdotes.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F1F0>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'Square Grouper: The Godfathers of Ganja', 'critics_pick': 0, 'headline': 'Adventures in the Drug Trades', 'publication_date': '2011-04-14', 'summary_short': '“Square Grouper” is a documentary about pot smuggling in South Florida in the 1970s and ’80s.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2E0E0>
# Hello
# msg
# {'mpaa_rating': 'PG-13', 'display_title': 'Tokyo Godfathers', 'critics_pick': 1, 'headline': 'Three Down-and-Outs Rescue a Foundling From the Trash', 'publication_date': '2004-01-16', 'summary_short': "Another marvel from Satoshi Kon, whose first two films, &quot;Perfect Blue&quot; and &quot;Millennium Actress,&quot; have already pushed Japanese feature-length animation toward greater realism and wilder fantasy. Loosely based on &quot;3 Godfathers,&quot; John Ford's maudlin 1948 western, this movie, a sweet fable of decency amid the down and out, also has echoes of Chaplin and Capra. Three homeless people — an embittered alcoholic, a middle-aged transvestite and a teenage runaway — find an abandoned baby on Christmas Eve. As they try to reunite the foundling with her parents, they revisit their own unhappy lives, and travel through a city rendered with unbelievable precision and tinted with undeniable love. The potentially sticky sentiments of the story are balanced by a crazily inventive narrative and by Mr. Kon's cool, obsessively detailed visual style. At the end, the skyscrapers of Tokyo wriggle and dance to a Japanese-language techno version of Beethoven's &quot;Ode to Joy,&quot; which pretty much sums up this indescribable, unforgettable movie. — A. O. Scott"}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EC48BB0>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather, Part III', 'critics_pick': 1, 'headline': 'GODFATHER PART III (MOVIE)', 'publication_date': '1990-12-25', 'summary_short': "Mafia heir trapped by legacy of past. Coppola's director's cut. Deeply moving."}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F700>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather, Part II', 'critics_pick': 1, 'headline': 'Godfather: Part II, The (Movie)', 'publication_date': '1974-12-13', 'summary_short': ''}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283ED8DA50>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Black Godfather', 'critics_pick': 0, 'headline': 'Black Godfather, The (Movie)', 'publication_date': '1974-09-04', 'summary_short': ''}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EC48BB0>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather', 'critics_pick': 1, 'headline': 'THE GODFATHER (MOVIE)', 'publication_date': '1972-03-16', 'summary_short': "Puzo's Mafioso novel. Scalding and memorable."}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F6D0>
# Hello
# msg
# {'mpaa_rating': 'Passed', 'display_title': 'Three Godfathers', 'critics_pick': 0, 'headline': 'Three Godfathers', 'publication_date': '1949-03-04', 'summary_short': 'Outlaw trio and abandoned child. Typical, expert Ford western.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283ED8D0C0>
# Hello
# msg
# {'mpaa_rating': 'Passed', 'display_title': 'Miracle in the Sand', 'critics_pick': 0, 'headline': 'Three Godfathers, The', 'publication_date': '1936-03-09', 'summary_short': 'Thieves reluctantly care for orphan. Tragic horse opera.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EDF11B0>
# Hello
# msg
# {'mpaa_rating': '', 'display_title': 'El Compadre Mendoza', 'critics_pick': 0, 'headline': 'Compadre Mendoza, El', 'publication_date': '1934-11-19', 'summary_short': 'Landowner survives Mexican Revolution by supporting both sides. Directed by Fernando de Fuentes.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283D1AAE60>
# Hello
# msg
# {'mpaa_rating': 'TV-MA', 'display_title': 'The Black Godfather', 'critics_pick': 0, 'headline': '‘The Black Godfather’ Review: The Music Executive Who Made It All Happen', 'publication_date': '2019-06-06', 'summary_short': 'Reginald Hudlin’s documentary about Clarence Avant includes many golden anecdotes.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EDF11B0>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'Square Grouper: The Godfathers of Ganja', 'critics_pick': 0, 'headline': 'Adventures in the Drug Trades', 'publication_date': '2011-04-14', 'summary_short': '“Square Grouper” is a documentary about pot smuggling in South Florida in the 1970s and ’80s.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EDF11E0>
# Hello
# msg
# {'mpaa_rating': 'PG-13', 'display_title': 'Tokyo Godfathers', 'critics_pick': 1, 'headline': 'Three Down-and-Outs Rescue a Foundling From the Trash', 'publication_date': '2004-01-16', 'summary_short': "Another marvel from Satoshi Kon, whose first two films, &quot;Perfect Blue&quot; and &quot;Millennium Actress,&quot; have already pushed Japanese feature-length animation toward greater realism and wilder fantasy. Loosely based on &quot;3 Godfathers,&quot; John Ford's maudlin 1948 western, this movie, a sweet fable of decency amid the down and out, also has echoes of Chaplin and Capra. Three homeless people — an embittered alcoholic, a middle-aged transvestite and a teenage runaway — find an abandoned baby on Christmas Eve. As they try to reunite the foundling with her parents, they revisit their own unhappy lives, and travel through a city rendered with unbelievable precision and tinted with undeniable love. The potentially sticky sentiments of the story are balanced by a crazily inventive narrative and by Mr. Kon's cool, obsessively detailed visual style. At the end, the skyscrapers of Tokyo wriggle and dance to a Japanese-language techno version of Beethoven's &quot;Ode to Joy,&quot; which pretty much sums up this indescribable, unforgettable movie. — A. O. Scott"}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283D1AAE60>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather, Part III', 'critics_pick': 1, 'headline': 'GODFATHER PART III (MOVIE)', 'publication_date': '1990-12-25', 'summary_short': "Mafia heir trapped by legacy of past. Coppola's director's cut. Deeply moving."}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283ED8D1B0>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather, Part II', 'critics_pick': 1, 'headline': 'Godfather: Part II, The (Movie)', 'publication_date': '1974-12-13', 'summary_short': ''}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283ED8CCA0>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Black Godfather', 'critics_pick': 0, 'headline': 'Black Godfather, The (Movie)', 'publication_date': '1974-09-04', 'summary_short': ''}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283D1AAE60>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather', 'critics_pick': 1, 'headline': 'THE GODFATHER (MOVIE)', 'publication_date': '1972-03-16', 'summary_short': "Puzo's Mafioso novel. Scalding and memorable."}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283ED8D780>
# Hello
# msg
# {'mpaa_rating': 'Passed', 'display_title': 'Three Godfathers', 'critics_pick': 0, 'headline': 'Three Godfathers', 'publication_date': '1949-03-04', 'summary_short': 'Outlaw trio and abandoned child. Typical, expert Ford western.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283ED8CCA0>
# Hello
# msg
# {'mpaa_rating': 'Passed', 'display_title': 'Miracle in the Sand', 'critics_pick': 0, 'headline': 'Three Godfathers, The', 'publication_date': '1936-03-09', 'summary_short': 'Thieves reluctantly care for orphan. Tragic horse opera.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F5B0>
# Hello
# msg
# {'mpaa_rating': '', 'display_title': 'El Compadre Mendoza', 'critics_pick': 0, 'headline': 'Compadre Mendoza, El', 'publication_date': '1934-11-19', 'summary_short': 'Landowner survives Mexican Revolution by supporting both sides. Directed by Fernando de Fuentes.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283D1AAE60>
# Hello
# msg
# {'mpaa_rating': 'TV-MA', 'display_title': 'The Black Godfather', 'critics_pick': 0, 'headline': '‘The Black Godfather’ Review: The Music Executive Who Made It All Happen', 'publication_date': '2019-06-06', 'summary_short': 'Reginald Hudlin’s documentary about Clarence Avant includes many golden anecdotes.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EDF11E0>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'Square Grouper: The Godfathers of Ganja', 'critics_pick': 0, 'headline': 'Adventures in the Drug Trades', 'publication_date': '2011-04-14', 'summary_short': '“Square Grouper” is a documentary about pot smuggling in South Florida in the 1970s and ’80s.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283ED8D1B0>
# Hello
# msg
# {'mpaa_rating': 'PG-13', 'display_title': 'Tokyo Godfathers', 'critics_pick': 1, 'headline': 'Three Down-and-Outs Rescue a Foundling From the Trash', 'publication_date': '2004-01-16', 'summary_short': "Another marvel from Satoshi Kon, whose first two films, &quot;Perfect Blue&quot; and &quot;Millennium Actress,&quot; have already pushed Japanese feature-length animation toward greater realism and wilder fantasy. Loosely based on &quot;3 Godfathers,&quot; John Ford's maudlin 1948 western, this movie, a sweet fable of decency amid the down and out, also has echoes of Chaplin and Capra. Three homeless people — an embittered alcoholic, a middle-aged transvestite and a teenage runaway — find an abandoned baby on Christmas Eve. As they try to reunite the foundling with her parents, they revisit their own unhappy lives, and travel through a city rendered with unbelievable precision and tinted with undeniable love. The potentially sticky sentiments of the story are balanced by a crazily inventive narrative and by Mr. Kon's cool, obsessively detailed visual style. At the end, the skyscrapers of Tokyo wriggle and dance to a Japanese-language techno version of Beethoven's &quot;Ode to Joy,&quot; which pretty much sums up this indescribable, unforgettable movie. — A. O. Scott"}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283ED8D780>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather, Part III', 'critics_pick': 1, 'headline': 'GODFATHER PART III (MOVIE)', 'publication_date': '1990-12-25', 'summary_short': "Mafia heir trapped by legacy of past. Coppola's director's cut. Deeply moving."}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283ED8CCA0>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather, Part II', 'critics_pick': 1, 'headline': 'Godfather: Part II, The (Movie)', 'publication_date': '1974-12-13', 'summary_short': ''}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EDF11B0>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Black Godfather', 'critics_pick': 0, 'headline': 'Black Godfather, The (Movie)', 'publication_date': '1974-09-04', 'summary_short': ''}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283ED8D8D0>
# Hello
# msg
# {'mpaa_rating': 'R', 'display_title': 'The Godfather', 'critics_pick': 1, 'headline': 'THE GODFATHER (MOVIE)', 'publication_date': '1972-03-16', 'summary_short': "Puzo's Mafioso novel. Scalding and memorable."}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F250>
# Hello
# msg
# {'mpaa_rating': 'Passed', 'display_title': 'Three Godfathers', 'critics_pick': 0, 'headline': 'Three Godfathers', 'publication_date': '1949-03-04', 'summary_short': 'Outlaw trio and abandoned child. Typical, expert Ford western.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EE2F580>
# Hello
# msg
# {'mpaa_rating': 'Passed', 'display_title': 'Miracle in the Sand', 'critics_pick': 0, 'headline': 'Three Godfathers, The', 'publication_date': '1936-03-09', 'summary_short': 'Thieves reluctantly care for orphan. Tragic horse opera.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EDF11E0>
# Hello
# msg
# {'mpaa_rating': '', 'display_title': 'El Compadre Mendoza', 'critics_pick': 0, 'headline': 'Compadre Mendoza, El', 'publication_date': '1934-11-19', 'summary_short': 'Landowner survives Mexican Revolution by supporting both sides. Directed by Fernando de Fuentes.'}
# Data inserted with record ids <pymongo.results.InsertOneResult object at 0x000002283EDF11B0>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [30], in <module>
# ----> 1 for msg in consumer:
#       2     print('Hello')
#       3     print('msg')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\kafka\consumer\group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\kafka\consumer\group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\kafka\consumer\group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\kafka\consumer\group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\kafka\consumer\group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\kafka\client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\kafka\client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\selectors.py:324, in SelectSelector.select(self, timeout)
#     322 ready = []
#     323 try:
# --> 324     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     325 except InterruptedError:
#     326     return ready
#
# File ~\AppData\Local\Programs\Python\Python310\lib\selectors.py:315, in SelectSelector._select(self, r, w, _, timeout)
#     314 def _select(self, r, w, _, timeout=None):
# --> 315     r, w, x = select.select(r, w, w, timeout)
#     316     return r, w + x, []
#
# KeyboardInterrupt:
